# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import numpy as np
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import matplotlib.pyplot as plt

from sklearn.model_selection import cross_val_predict

# %%
df = pd.read_csv('cleaned_data.csv') 
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head(5)
# Out:
#     NewID   Category                                              Title  \
# 0  N88753  lifestyle  brands queen elizabeth prince charles prince p...
# 1  N45436       news            walmart slash price lastgeneration ipad
# 2  N23144     health                                bad habit belly fat
# 3  N93187       news         cost trumps aid freeze trench ukraines war
# 4  N75236     health                 nba wife here affect mental health
#
#                                             Abstract
# 0     shop notebooks jacket royal ca nt live without
# 1  apple new ipad release bring big deal last yea...
# 2  seemingly harmless habit hold back keep shed u...
# 3  lt ivan molchanet peek parapet sand bag front ...
# 4  feel like fraud nba wife did nt help fact near...

# %%
test_df = pd.read_csv('test.csv')
test_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
test_df.head(5)
# Out:
#      NewID Category                                              Title  \
# 0   N87253   sports  Cam Heyward named NFLPA Community MVP of the Week
# 1   N96113     news  More Galaxy S11 versions will support 5G conne...
# 2  N117651   sports  Panthers mailbag: Cam Newton's future in Carol...
# 3   N66784   sports  Notre Dame Stadium will not be sold out for fi...
# 4   N80122   sports     4 key things to know about Chargers vs. Chiefs
#
#                                             Abstract
# 0  Cameron Heyward receives a great off field hon...
# 1  The Galaxy S11's design has been finished, a l...
# 2  Oh, the takes. So, so many takes. The Carolina...
# 3  Not since Thanksgiving Day 1973 had Notre Dame...
# 4                                                NaN

# %% [markdown]
# ### Combining the feature columns Title and Abstract in training data

# %%
df['News'] = df['Title'].str.cat(df['Abstract'],sep=" ")
df.dropna(subset = ["News"], inplace=True)

print('Length of the training dataset ', len(df))
df.head()
# Out:
# Length of the training dataset  77077
#     NewID   Category                                              Title  \
# 0  N88753  lifestyle  brands queen elizabeth prince charles prince p...
# 1  N45436       news            walmart slash price lastgeneration ipad
# 2  N23144     health                                bad habit belly fat
# 3  N93187       news         cost trumps aid freeze trench ukraines war
# 4  N75236     health                 nba wife here affect mental health
#
#                                             Abstract  \
# 0     shop notebooks jacket royal ca nt live without
# 1  apple new ipad release bring big deal last yea...
# 2  seemingly harmless habit hold back keep shed u...
# 3  lt ivan molchanet peek parapet sand bag front ...
# 4  feel like fraud nba wife did nt help fact near...
#
#                                                 News
# 0  brands queen elizabeth prince charles prince p...
# 1  walmart slash price lastgeneration ipad apple ...
# 2   bad habit belly fat seemingly harmless habit ...
# 3  cost trumps aid freeze trench ukraines war lt ...
# 4  nba wife here affect mental health feel like f...

# %% [markdown]
# ### Combining the feature columns Title and Abstract in test data

# %%
test_df['News'] = test_df['Title'].str.cat(test_df['Abstract'],sep=" ")
test_df.dropna(subset = ["News"], inplace=True)

# %% [markdown]
# ### Applying Bag of Words and TF-IDF on the training data

# %%
x_title_abstract_train, y_title_abstract_train = df.News.values, df.Category.values

# Vectorizing the text values using CountVectorizer
count_vectorizer = CountVectorizer() 
TA_CVec = count_vectorizer.fit_transform(x_title_abstract_train)

# Applying tf-idf to the news column using TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(TA_CVec)

# %% [markdown]
# ### Applying Bag of Words and TF-IDF on the test data

# %%
feature_test_news, label_test_news = test_df.News.values, test_df.Category.values
Feature_test_news = count_vectorizer.transform(feature_test_news)
Feature_test_news_cleaned = tfidf_transformer.fit_transform(Feature_test_news)

# %% [markdown]
# ### Fitting the Logistic Regression model on the training data

# %%
model_news = LogisticRegression(max_iter=1000)
model_news.fit(X_train_tfidf, y_title_abstract_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ### Performing cross-validation on the training data

# %%
predicted_train = cross_val_predict(model_news, X_train_tfidf, y_title_abstract_train, cv=5)
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %% [markdown]
# ### Evaluating model on the test data

# %%
predicted_test = model_news.predict(Feature_test_news_cleaned)

# %% [markdown]
# ### Evaluating model accuracy

# %%
# Evaluate accuracy on the test data
accuracy_test = accuracy_score(label_test_news, predicted_test)
print("Accuracy on Test Data:", accuracy_test)
# Out:
# Accuracy on Test Data: 0.7273827056595834

# %% [markdown]
# ### Classification Report

# %%
print("Classification Report on Test Data:")
print(classification_report(label_test_news, predicted_test))
# Out:
# Classification Report on Test Data:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
#         autos       0.65      0.48      0.55       436
# entertainment       0.62      0.19      0.29       111
#       finance       0.60      0.46      0.52      1064
#  foodanddrink       0.73      0.66      0.69       731
#        health       0.73      0.50      0.59       417
#          kids       0.00      0.00      0.00        16
#     lifestyle       0.40      0.28      0.33       587
#        movies       0.67      0.30      0.41       127
#         music       0.81      0.44      0.57       278
#          news       0.65      0.85      0.74      6076
#  northamerica       0.00      0.00      0.00         1
#        sports       0.87      0.96      0.92      6090
#        travel       0.57      0.32      0.41       951
#            tv       0.66      0.16      0.26       227
#         video       0.68      0.22      0.34      1086
#       weather       0.78      0.57      0.66       814
#
#      accuracy                           0.73     19012
#     macro avg       0.59      0.40      0.46     19012
#  weighted avg       0.72      0.73      0.70     19012
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Confusion Matrix

# %%
label = ['sports', 'news', 'finance', 'autos', 'lifestyle', 'travel', 'weather', 'health',
 'video', 'foodanddrink', 'movies', 'tv', 'music', 'entertainment', 'kids',
 'northamerica']
c_m = confusion_matrix(label_test_news, predicted_test, labels = label)

#Plot the confusion matrix
plt.figure(figsize=(10,10))
sns.heatmap(pd.DataFrame(c_m, label, label), annot=True, fmt='d', cmap='viridis')
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2c41a900-ec3b-423b-ace8-d13b9a16907d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
